# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
db_config = {'host':  'pg-20dc39ce-larissabatistarangel.k.aivencloud.com',
                           'user' : 'avnadmin',
                           'password' : 'AVNS_iBcVxpX-mQhYYwXZVSy',
                           'port' : '16523',
                           'database' : 'defaultdb'}

conn = psycopg2.connect(**db_config)

# %%
pd.read_sql_query("""
SELECT * FROM APARELHO
where disponivel = true;

""",conn)
# Out:
# <ipython-input-5-a79f820a5d4d>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo          marca  disponivel
# 0       1        Philips        True
# 1       3  GE Healthcare        True
# 2       4        Toshiba        True
# 3       6       Fujifilm        True
# 4       9           Agfa        True
# 5      10        Mindray        True
# 6      12        Hologic        True
# 7      13        Biplane        True
# 8      15      Medtronic        True
# 9       7         Toyota        True

# %%
pd.read_sql_query("""
SELECT * FROM REGISTRO_EXAME
WHERE condicaoEhPatologica = true;

""",conn)
# Out:
# <ipython-input-12-3d71b84da101>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo   data_hora_geracao  condicaoehpatologica  fk_exame_codigo
# 0       2 2024-08-02 15:20:00                  True                2
# 1       3 2024-08-02 16:30:00                  True                3
# 2       5 2024-08-02 18:45:00                  True                5
# 3       7 2024-08-03 09:45:00                  True                7
# 4       9 2024-08-03 11:00:00                  True                9
# 5      10 2024-08-03 11:30:00                  True               10
# 6      12 2024-08-03 12:45:00                  True               12
# 7      14 2024-08-03 14:00:00                  True               14

# %%
pd.read_sql_query("""
SELECT * FROM EXAME
WHERE data_hora_realizacao BETWEEN '2024-08-01 00:00:00' AND '2024-08-05 23:59:59';

""",conn)
# Out:
# <ipython-input-6-9819537fcdb5>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo data_hora_realizacao  fk_paciente_codigo  fk_aparelho_codigo
# 0       1  2024-08-01 08:30:00                   1                   3
# 1       2  2024-08-02 09:00:00                   2                   5
# 2       3  2024-08-03 10:15:00                   3                   7
# 3       4  2024-08-04 11:45:00                   4                   2
# 4       5  2024-08-05 12:00:00                   5                   4

# %%
pd.read_sql_query("""
SELECT * FROM RADIOLOGISTA WHERE disponivel = true;

""",conn)
# Out:
# <ipython-input-14-0ed6142a6ee3>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo          cpf          nome  disponivel
# 0       1  12332123200       Beiçola        True
# 1       2  98765432199     Dr. House        True
# 2       4  76543210977       Dr. Cox        True
# 3       5  65432109876    Dr. Watson        True
# 4       7  43210987654     Dr. Smith        True
# 5       8  32109876543  Dra. Johnson        True
# 6      10  10987654321    Dra. Davis        True
# 7      11   9876543210  Dr. Martinez        True
# 8      13  76543219876     Dr. Lewis        True
# 9      14  65432108765    Dra. Clark        True

# %%
pd.read_sql_query("""
SELECT * FROM APARELHO
WHERE (marca = 'Philips' OR marca = 'Siemens')
  AND disponivel = true;
""",conn)
# Out:
# <ipython-input-15-2002a11d7fa7>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo    marca  disponivel
# 0       1  Philips        True

# %%
pd.read_sql_query("""
SELECT * FROM PREDICAO
WHERE confiabilidade > 0.9
  AND NOT fk_patologia_codigo = 2;


""",conn)
# Out:
# <ipython-input-18-e7d31851e733>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo  fk_patologia_codigo  fk_registro_exame_codigo  confiabilidade
# 0       9                    3                         9            0.92
# 1      15                    3                        15            0.91
# 2      18                    3                         3            0.93
# 3      30                    3                        15            0.91
# 4      39                    3                         9            0.92

# %%
pd.read_sql_query("""
SELECT * FROM EXAME
WHERE data_hora_realizacao > '2024-08-07'
  OR fk_aparelho_codigo = 7;
""",conn)
# Out:
# <ipython-input-22-f7df2bd1d7c7>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo data_hora_realizacao  fk_paciente_codigo  fk_aparelho_codigo
# 0       3  2024-08-03 10:15:00                   3                   7
# 1       7  2024-08-07 14:00:00                   7                   6
# 2       8  2024-08-08 15:30:00                   8                   8
# 3       9  2024-08-09 16:00:00                   9                   3
# 4      10  2024-08-10 08:45:00                  10                   5
# 5      11  2024-08-11 09:30:00                  11                   7
# 6      12  2024-08-12 10:00:00                  12                   2
# 7      13  2024-08-13 11:30:00                  13                   4
# 8      14  2024-08-14 12:15:00                  14                   6
# 9      15  2024-08-15 13:00:00                  15                   8

# %%
pd.read_sql_query("""
SELECT * FROM REGISTRO_EXAME
WHERE condicaoEhPatologica = true
  AND data_hora_geracao > '2024-08-02';


""",conn)
# Out:
# <ipython-input-23-744145306e13>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo   data_hora_geracao  condicaoehpatologica  fk_exame_codigo
# 0       2 2024-08-02 15:20:00                  True                2
# 1       3 2024-08-02 16:30:00                  True                3
# 2       5 2024-08-02 18:45:00                  True                5
# 3       7 2024-08-03 09:45:00                  True                7
# 4       9 2024-08-03 11:00:00                  True                9
# 5      10 2024-08-03 11:30:00                  True               10
# 6      12 2024-08-03 12:45:00                  True               12
# 7      14 2024-08-03 14:00:00                  True               14

# %%
pd.read_sql_query("""
SELECT * FROM REGISTRO_EXAME
WHERE NOT condicaoEhPatologica = true;


""",conn)
# Out:
# <ipython-input-25-560fbe8d41ad>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo   data_hora_geracao  condicaoehpatologica  fk_exame_codigo
# 0       1 2024-08-02 14:50:00                 False                1
# 1       4 2024-08-02 18:00:00                 False                4
# 2       6 2024-08-03 09:15:00                 False                6
# 3       8 2024-08-03 10:15:00                 False                8
# 4      11 2024-08-03 12:00:00                 False               11
# 5      13 2024-08-03 13:15:00                 False               13
# 6      15 2024-08-03 14:30:00                 False               15

# %%
pd.read_sql_query("""
SELECT nome, EXTRACT(YEAR FROM AGE(CURRENT_DATE, data_nasc)) AS idade
FROM PACIENTE;


""",conn)
# Out:
# <ipython-input-26-a400af368329>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#                nome   idade
# 0        Joana Darc   612.0
# 1     Marcelo Rossi    57.0
# 2    Carlinhos Maia    33.0
# 3   Edgar Allan Poe   215.0
# 4       Franz Kafka   141.0
# 5      Bola de Neve    79.0
# 6          Garfield    46.0
# 7     Homer Simpson    68.0
# 8      Bart Simpson    45.0
# 9       Don Quixote   419.0
# 10  Winnie the Pooh   102.0
# 11            Shrek    23.0
# 12        Chewbacca  2016.0
# 13          Pikachu    28.0
# 14          Smeagol  -405.0

# %%
pd.read_sql_query("""
SELECT codigo, fk_patologia_codigo, fk_registro_exame_codigo, confiabilidade,
    confiabilidade * 100 AS confiabilidade_porcentagem
FROM PREDICAO;


""",conn)
# Out:
# <ipython-input-27-e2e9d06bda69>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     codigo  fk_patologia_codigo  fk_registro_exame_codigo  confiabilidade  \
# 0        1                    1                         1            0.85
# 1        2                    2                         2            0.75
# 2        3                    3                         3            0.90
# 3        4                    1                         4            0.80
# 4        5                    2                         5            0.70
# 5        6                    3                         6            0.88
# 6        7                    1                         7            0.83
# 7        8                    2                         8            0.77
# 8        9                    3                         9            0.92
# 9       10                    1                        10            0.81
# 10      11                    2                        11            0.73
# 11      12                    3                        12            0.89
# 12      13                    1                        13            0.82
# 13      14                    2                        14            0.76
# 14      15                    3                        15            0.91
# 15      16                    1                         1            0.84
# 16      17                    2                         2            0.78
# 17      18                    3                         3            0.93
# 18      19                    1                         4            0.80
# 19      20                    2                         5            0.72
# 20      21                    3                         6            0.87
# 21      22                    1                         7            0.79
# 22      23                    2                         8            0.74
# 23      24                    3                         9            0.90
# 24      25                    1                        10            0.85
# 25      26                    2                        11            0.71
# 26      27                    3                        12            0.88
# 27      28                    1                        13            0.80
# 28      29                    2                        14            0.77
# 29      30                    3                        15            0.91
# 30      31                    1                         1            0.82
# 31      32                    2                         2            0.72
# 32      33                    3                         3            0.89
# 33      34                    1                         4            0.83
# 34      35                    2                         5            0.75
# 35      36                    3                         6            0.90
# 36      37                    1                         7            0.81
# 37      38                    2                         8            0.78
# 38      39                    3                         9            0.92
# 39      40                    1                        10            0.84
# 40      41                    2                        11            0.76
# 41      42                    3                        12            0.89
# 42      43                    1                        13            0.80
# 43      44                    2                        14            0.73
# 44      45                    3                        15            0.90
# 45      46                    1                         1            0.82
# 46      47                    2                         2            0.74
# 47      48                    3                         3            0.88
# 48      49                    1                         4            0.79
# 49      50                    2                         5            0.76
#
#     confiabilidade_porcentagem
# 0                         85.0
# 1                         75.0
# 2                         90.0
# 3                         80.0
# 4                         70.0
# 5                         88.0
# 6                         83.0
# 7                         77.0
# 8                         92.0
# 9                         81.0
# 10                        73.0
# 11                        89.0
# 12                        82.0
# 13                        76.0
# 14                        91.0
# 15                        84.0
# 16                        78.0
# 17                        93.0
# 18                        80.0
# 19                        72.0
# 20                        87.0
# 21                        79.0
# 22                        74.0
# 23                        90.0
# 24                        85.0
# 25                        71.0
# 26                        88.0
# 27                        80.0
# 28                        77.0
# 29                        91.0
# 30                        82.0
# 31                        72.0
# 32                        89.0
# 33                        83.0
# 34                        75.0
# 35                        90.0
# 36                        81.0
# 37                        78.0
# 38                        92.0
# 39                        84.0
# 40                        76.0
# 41                        89.0
# 42                        80.0
# 43                        73.0
# 44                        90.0
# 45                        82.0
# 46                        74.0
# 47                        88.0
# 48                        79.0
# 49                        76.0

# %%
pd.read_sql_query("""
SELECT
    AVG(confiabilidade) AS media_confiabilidade
FROM
    PREDICAO;



""",conn)
# Out:
# <ipython-input-28-567b01d49514>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    media_confiabilidade
# 0                0.8188

# %%
pd.read_sql_query("""
select * from aparelho
where marca like 'S%';

""",conn)
# Out:
# <ipython-input-16-c02492031707>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo     marca  disponivel
# 0       2   Siemens       False
# 1       7   Samsung        True
# 2      14  Shimadzu       False

# %%
pd.read_sql_query("""
SELECT * FROM EXAME
WHERE TO_CHAR(data_hora_realizacao, 'YYYY') LIKE '2024%';


""",conn)
# Out:
# <ipython-input-11-16dd41bb93e9>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     codigo data_hora_realizacao  fk_paciente_codigo  fk_aparelho_codigo
# 0        1  2024-08-01 08:30:00                   1                   3
# 1        2  2024-08-02 09:00:00                   2                   5
# 2        3  2024-08-03 10:15:00                   3                   7
# 3        4  2024-08-04 11:45:00                   4                   2
# 4        5  2024-08-05 12:00:00                   5                   4
# 5        6  2024-08-06 13:30:00                   6                   1
# 6        7  2024-08-07 14:00:00                   7                   6
# 7        8  2024-08-08 15:30:00                   8                   8
# 8        9  2024-08-09 16:00:00                   9                   3
# 9       10  2024-08-10 08:45:00                  10                   5
# 10      11  2024-08-11 09:30:00                  11                   7
# 11      12  2024-08-12 10:00:00                  12                   2
# 12      13  2024-08-13 11:30:00                  13                   4
# 13      14  2024-08-14 12:15:00                  14                   6
# 14      15  2024-08-15 13:00:00                  15                   8

# %%
pd.read_sql_query("""
select * from radiologista
where nome like '%santos';
""",conn)
# Out:
# <ipython-input-17-c6ccfaee3ff8>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
# Empty DataFrame
# Columns: [codigo, cpf, nome, disponivel]
# Index: []

# %%
pd.read_sql_query("""
select * from exame
where data_hora_realizacao::text like '____-07-%';

""",conn)
# Out:
# <ipython-input-25-cac97a7dae0e>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
# Empty DataFrame
# Columns: [codigo, data_hora_realizacao, fk_paciente_codigo, fk_aparelho_codigo]
# Index: []

# %%
pd.read_sql_query("""
select * from paciente
where data_nasc::text like '2001%';

""",conn)
# Out:
# <ipython-input-27-2c3a679b5a89>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo          cpf   nome   data_nasc      id
# 0      12  32109876500  Shrek  2001-03-18  ID8889

# %%
pd.read_sql_query("""
SELECT * FROM PACIENTE
WHERE id LIKE 'ID__7%';


""",conn)
# Out:
# <ipython-input-10-f30394aed1a8>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    codigo          cpf             nome   data_nasc      id
# 0       3  34567898700   Carlinhos Maia  1991-05-12  ID7071
# 1       4  23434545600  Edgar Allan Poe  1809-01-19  ID7273
# 2       5   7056912399      Franz Kafka  1883-06-02  ID7475
# 3       6  98765432100     Bola de Neve  1945-03-20  ID7677
# 4       7  87654321000         Garfield  1978-06-19  ID7879

# %%
pd.read_sql_query("""
select * from patologia
where nivel_gravidade::text like '[4]';



""",conn)
# Out:
# <ipython-input-14-16fb284e1a3c>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
# Empty DataFrame
# Columns: [codigo, nome, nivel_gravidade]
# Index: []

# %% [markdown]
# https://colab.research.google.com/drive/19KaUKHYjk2WrfzGlfKl_lRcUl4wYqiIR?usp=sharing

# %%
pd.read_sql_query("""
select * from patologia
where nivel_gravidade::text like '3%'
   or nivel_gravidade::text like '4%'
   or nivel_gravidade::text like '5%';
""",conn)
# Out:
# <ipython-input-15-5fa2984146fe>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     codigo                         nome  nivel_gravidade
# 0        3                    Pneumonia                3
# 1        4             Fratura de Fêmur                4
# 2        5                   Apendicite                4
# 3        6              Diabetes Tipo 1                3
# 4        7              Diabetes Tipo 2                4
# 5        8         Hipertensão Arterial                3
# 6        9             Câncer de Pulmão                5
# 7       10               Câncer de Mama                4
# 8       13                  Tuberculose                4
# 9       14  Doença Arterial Coronariana                5
# 10      15               Hepatite Viral                4

# %%
pd.read_sql_query("""
select p.nome as paciente_nome, e.data_hora_realizacao, a.marca as aparelho_marca, r.data_hora_geracao as registro_data, la.data_hora_geracao as laudo_data, r.condicaoehpatologica, pr.confiabilidade, pa.nome as patologia_nome from paciente p inner join exame e on p.codigo = e.fk_paciente_codigo inner join aparelho a on e.fk_aparelho_codigo = a.codigo inner join registro_exame r on e.codigo = r.fk_exame_codigo inner join laudo la on r.codigo = la.fk_exame_codigo inner join predicao pr on r.codigo = pr.fk_registro_exame_codigo inner join patologia pa on pr.fk_patologia_codigo = pa.codigo order by p.nome, e.data_hora_realizacao;



""",conn)
# Out:
# <ipython-input-30-db1228c56d14>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#       paciente_nome data_hora_realizacao aparelho_marca       registro_data  \
# 0      Bart Simpson  2024-08-09 16:00:00  GE Healthcare 2024-08-03 11:00:00
# 1      Bart Simpson  2024-08-09 16:00:00  GE Healthcare 2024-08-03 11:00:00
# 2      Bart Simpson  2024-08-09 16:00:00  GE Healthcare 2024-08-03 11:00:00
# 3      Bola de Neve  2024-08-06 13:30:00        Philips 2024-08-03 09:15:00
# 4      Bola de Neve  2024-08-06 13:30:00        Philips 2024-08-03 09:15:00
# 5      Bola de Neve  2024-08-06 13:30:00        Philips 2024-08-03 09:15:00
# 6    Carlinhos Maia  2024-08-03 10:15:00         Toyota 2024-08-02 16:30:00
# 7    Carlinhos Maia  2024-08-03 10:15:00         Toyota 2024-08-02 16:30:00
# 8    Carlinhos Maia  2024-08-03 10:15:00         Toyota 2024-08-02 16:30:00
# 9    Carlinhos Maia  2024-08-03 10:15:00         Toyota 2024-08-02 16:30:00
# 10        Chewbacca  2024-08-13 11:30:00        Toshiba 2024-08-03 13:15:00
# 11        Chewbacca  2024-08-13 11:30:00        Toshiba 2024-08-03 13:15:00
# 12        Chewbacca  2024-08-13 11:30:00        Toshiba 2024-08-03 13:15:00
# 13      Don Quixote  2024-08-10 08:45:00          Canon 2024-08-03 11:30:00
# 14      Don Quixote  2024-08-10 08:45:00          Canon 2024-08-03 11:30:00
# 15      Don Quixote  2024-08-10 08:45:00          Canon 2024-08-03 11:30:00
# 16  Edgar Allan Poe  2024-08-04 11:45:00        Siemens 2024-08-02 18:00:00
# 17  Edgar Allan Poe  2024-08-04 11:45:00        Siemens 2024-08-02 18:00:00
# 18  Edgar Allan Poe  2024-08-04 11:45:00        Siemens 2024-08-02 18:00:00
# 19  Edgar Allan Poe  2024-08-04 11:45:00        Siemens 2024-08-02 18:00:00
# 20         Garfield  2024-08-07 14:00:00       Fujifilm 2024-08-03 09:45:00
# 21         Garfield  2024-08-07 14:00:00       Fujifilm 2024-08-03 09:45:00
# 22         Garfield  2024-08-07 14:00:00       Fujifilm 2024-08-03 09:45:00
# 23       Joana Darc  2024-08-01 08:30:00  GE Healthcare 2024-08-02 14:50:00
# 24       Joana Darc  2024-08-01 08:30:00  GE Healthcare 2024-08-02 14:50:00
# 25       Joana Darc  2024-08-01 08:30:00  GE Healthcare 2024-08-02 14:50:00
# 26       Joana Darc  2024-08-01 08:30:00  GE Healthcare 2024-08-02 14:50:00
# 27            Shrek  2024-08-12 10:00:00        Siemens 2024-08-03 12:45:00
# 28            Shrek  2024-08-12 10:00:00        Siemens 2024-08-03 12:45:00
# 29            Shrek  2024-08-12 10:00:00        Siemens 2024-08-03 12:45:00
# 30          Smeagol  2024-08-15 13:00:00        Hitachi 2024-08-03 14:30:00
# 31          Smeagol  2024-08-15 13:00:00        Hitachi 2024-08-03 14:30:00
# 32          Smeagol  2024-08-15 13:00:00        Hitachi 2024-08-03 14:30:00
#
#             laudo_data  condicaoehpatologica  confiabilidade   patologia_nome
# 0  2024-08-09 15:00:00                  True            0.92        Pneumonia
# 1  2024-08-09 15:00:00                  True            0.92        Pneumonia
# 2  2024-08-09 15:00:00                  True            0.90        Pneumonia
# 3  2024-08-06 12:00:00                 False            0.88  Diabetes Tipo 2
# 4  2024-08-06 12:00:00                 False            0.90        Pneumonia
# 5  2024-08-06 12:00:00                 False            0.87  Diabetes Tipo 2
# 6  2024-08-03 17:00:00                  True            0.93        Pneumonia
# 7  2024-08-03 17:00:00                  True            0.90  Diabetes Tipo 2
# 8  2024-08-03 17:00:00                  True            0.88        Pneumonia
# 9  2024-08-03 17:00:00                  True            0.89        Pneumonia
# 10 2024-08-13 11:00:00                 False            0.80     Saúde Normal
# 11 2024-08-13 11:00:00                 False            0.80     Saúde Normal
# 12 2024-08-13 11:00:00                 False            0.82     Saúde Normal
# 13 2024-08-10 16:00:00                  True            0.81     Saúde Normal
# 14 2024-08-10 16:00:00                  True            0.84     Saúde Normal
# 15 2024-08-10 16:00:00                  True            0.85     Saúde Normal
# 16 2024-08-04 10:00:00                 False            0.83     Saúde Normal
# 17 2024-08-04 10:00:00                 False            0.80     Saúde Normal
# 18 2024-08-04 10:00:00                 False            0.79     Saúde Normal
# 19 2024-08-04 10:00:00                 False            0.80     Saúde Normal
# 20 2024-08-07 13:00:00                  True            0.83     Saúde Normal
# 21 2024-08-07 13:00:00                  True            0.81     Saúde Normal
# 22 2024-08-07 13:00:00                  True            0.79     Saúde Normal
# 23 2024-08-01 15:00:00                 False            0.82     Saúde Normal
# 24 2024-08-01 15:00:00                 False            0.82     Saúde Normal
# 25 2024-08-01 15:00:00                 False            0.84     Saúde Normal
# 26 2024-08-01 15:00:00                 False            0.85     Saúde Normal
# 27 2024-08-12 10:00:00                  True            0.88        Pneumonia
# 28 2024-08-12 10:00:00                  True            0.89        Pneumonia
# 29 2024-08-12 10:00:00                  True            0.89  Diabetes Tipo 2
# 30 2024-08-15 13:00:00                 False            0.90        Pneumonia
# 31 2024-08-15 13:00:00                 False            0.91        Pneumonia
# 32 2024-08-15 13:00:00                 False            0.91        Pneumonia

# %%
pd.read_sql_query("""
select
    e.codigo as exame_codigo,
    e.data_hora_realizacao,
    r.nome as radiologista_nome,
    la.data_hora_geracao as laudo_data
from exame e
inner join laudo la on e.codigo = la.fk_exame_codigo
inner join radiologista r on la.fk_radiologista_codigo = r.codigo
order by r.nome, e.data_hora_realizacao;



""",conn)
# Out:
# <ipython-input-31-7c29939ca3a4>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     exame_codigo data_hora_realizacao radiologista_nome          laudo_data
# 0              9  2024-08-09 16:00:00           Beiçola 2024-08-09 15:00:00
# 1              2  2024-08-02 09:00:00        Dra. Clark 2024-08-02 16:00:00
# 2              8  2024-08-08 15:30:00        Dra. Davis 2024-08-08 14:00:00
# 3              1  2024-08-01 08:30:00      Dra. Johnson 2024-08-01 15:00:00
# 4             15  2024-08-15 13:00:00   Dra. Lexie Grey 2024-08-15 13:00:00
# 5             14  2024-08-14 12:15:00     Dra. Thompson 2024-08-14 12:00:00
# 6             11  2024-08-11 09:30:00       Dra. Wilson 2024-08-11 17:00:00
# 7             13  2024-08-13 11:30:00         Dr. Brown 2024-08-13 11:00:00
# 8             12  2024-08-12 10:00:00           Dr. Cox 2024-08-12 10:00:00
# 9              5  2024-08-05 12:00:00         Dr. House 2024-08-05 11:00:00
# 10            10  2024-08-10 08:45:00           Dr. Lee 2024-08-10 16:00:00
# 11             6  2024-08-06 13:30:00         Dr. Lewis 2024-08-06 12:00:00
# 12             4  2024-08-04 11:45:00      Dr. Martinez 2024-08-04 10:00:00
# 13             7  2024-08-07 14:00:00         Dr. Smith 2024-08-07 13:00:00
# 14             3  2024-08-03 10:15:00        Dr. Watson 2024-08-03 17:00:00

# %%
pd.read_sql_query("""
CREATE VIEW ExameDetalhado AS
SELECT
    e.codigo AS ExameCodigo,
    e.data_hora_realizacao AS DataRealizacao,
    pa.nome AS NomePaciente,
    a.marca AS MarcaAparelho,
    r.nome AS NomeRadiologista,
    (SELECT COUNT(*)
     FROM patologia_laudo pl
     JOIN patologia p ON pl.fk_patologia_codigo = p.codigo
     WHERE pl.fk_laudo_codigo = l.codigo) AS TotalPatologias
FROM
    exame e
LEFT JOIN
    paciente pa ON e.fk_paciente_codigo = pa.codigo
LEFT JOIN
    aparelho a ON e.fk_aparelho_codigo = a.codigo
LEFT JOIN
    laudo l ON l.fk_exame_codigo = e.codigo
LEFT JOIN
    radiologista r ON l.fk_radiologista_codigo = r.codigo;

SELECT * FROM ExameDetalhado;

""",conn)
# Out:
# <ipython-input-15-8dfb0169734c>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     examecodigo      datarealizacao     nomepaciente  marcaaparelho  \
# 0             1 2024-08-01 08:30:00       Joana Darc  GE Healthcare
# 1             2 2024-08-02 09:00:00    Marcelo Rossi          Canon
# 2             3 2024-08-03 10:15:00   Carlinhos Maia         Toyota
# 3             4 2024-08-04 11:45:00  Edgar Allan Poe        Siemens
# 4             5 2024-08-05 12:00:00      Franz Kafka        Toshiba
# 5             6 2024-08-06 13:30:00     Bola de Neve        Philips
# 6             7 2024-08-07 14:00:00         Garfield       Fujifilm
# 7             8 2024-08-08 15:30:00    Homer Simpson        Hitachi
# 8             9 2024-08-09 16:00:00     Bart Simpson  GE Healthcare
# 9            10 2024-08-10 08:45:00      Don Quixote          Canon
# 10           11 2024-08-11 09:30:00  Winnie the Pooh         Toyota
# 11           12 2024-08-12 10:00:00            Shrek        Siemens
# 12           13 2024-08-13 11:30:00        Chewbacca        Toshiba
# 13           14 2024-08-14 12:15:00          Pikachu       Fujifilm
# 14           15 2024-08-15 13:00:00          Smeagol        Hitachi
#
#    nomeradiologista  totalpatologias
# 0      Dra. Johnson                3
# 1        Dra. Clark                3
# 2        Dr. Watson                2
# 3      Dr. Martinez                2
# 4         Dr. House                1
# 5         Dr. Lewis                3
# 6         Dr. Smith                2
# 7        Dra. Davis                4
# 8           Beiçola                2
# 9           Dr. Lee                3
# 10      Dra. Wilson                4
# 11          Dr. Cox                3
# 12        Dr. Brown                3
# 13    Dra. Thompson                4
# 14  Dra. Lexie Grey                4

# %%
pd.read_sql_query("""
select
    p.nome as paciente_nome,
    e.data_hora_realizacao,
    pa.nome as patologia_nome,
    pa.nivel_gravidade
from paciente p
inner join exame e on p.codigo = e.fk_paciente_codigo
inner join registro_exame r on e.codigo = r.fk_exame_codigo
inner join predicao pr on r.codigo = pr.fk_registro_exame_codigo
inner join patologia pa on pr.fk_patologia_codigo = pa.codigo
order by p.nome, pa.nivel_gravidade desc;

""",conn)
# Out:
# <ipython-input-32-524b55ef3eba>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#       paciente_nome data_hora_realizacao   patologia_nome  nivel_gravidade
# 0      Bart Simpson  2024-08-09 16:00:00        Pneumonia                3
# 1      Bart Simpson  2024-08-09 16:00:00        Pneumonia                3
# 2      Bart Simpson  2024-08-09 16:00:00        Pneumonia                3
# 3      Bola de Neve  2024-08-06 13:30:00  Diabetes Tipo 2                4
# 4      Bola de Neve  2024-08-06 13:30:00  Diabetes Tipo 2                4
# 5      Bola de Neve  2024-08-06 13:30:00        Pneumonia                3
# 6    Carlinhos Maia  2024-08-03 10:15:00  Diabetes Tipo 2                4
# 7    Carlinhos Maia  2024-08-03 10:15:00        Pneumonia                3
# 8    Carlinhos Maia  2024-08-03 10:15:00        Pneumonia                3
# 9    Carlinhos Maia  2024-08-03 10:15:00        Pneumonia                3
# 10        Chewbacca  2024-08-13 11:30:00     Saúde Normal                1
# 11        Chewbacca  2024-08-13 11:30:00     Saúde Normal                1
# 12        Chewbacca  2024-08-13 11:30:00     Saúde Normal                1
# 13      Don Quixote  2024-08-10 08:45:00     Saúde Normal                1
# 14      Don Quixote  2024-08-10 08:45:00     Saúde Normal                1
# 15      Don Quixote  2024-08-10 08:45:00     Saúde Normal                1
# 16  Edgar Allan Poe  2024-08-04 11:45:00     Saúde Normal                1
# 17  Edgar Allan Poe  2024-08-04 11:45:00     Saúde Normal                1
# 18  Edgar Allan Poe  2024-08-04 11:45:00     Saúde Normal                1
# 19  Edgar Allan Poe  2024-08-04 11:45:00     Saúde Normal                1
# 20         Garfield  2024-08-07 14:00:00     Saúde Normal                1
# 21         Garfield  2024-08-07 14:00:00     Saúde Normal                1
# 22         Garfield  2024-08-07 14:00:00     Saúde Normal                1
# 23       Joana Darc  2024-08-01 08:30:00     Saúde Normal                1
# 24       Joana Darc  2024-08-01 08:30:00     Saúde Normal                1
# 25       Joana Darc  2024-08-01 08:30:00     Saúde Normal                1
# 26       Joana Darc  2024-08-01 08:30:00     Saúde Normal                1
# 27            Shrek  2024-08-12 10:00:00  Diabetes Tipo 2                4
# 28            Shrek  2024-08-12 10:00:00        Pneumonia                3
# 29            Shrek  2024-08-12 10:00:00        Pneumonia                3
# 30          Smeagol  2024-08-15 13:00:00        Pneumonia                3
# 31          Smeagol  2024-08-15 13:00:00        Pneumonia                3
# 32          Smeagol  2024-08-15 13:00:00        Pneumonia                3

# %%
pd.read_sql_query("""
select
    a.marca as aparelho_marca,
    a.disponivel,
    e.data_hora_realizacao
from aparelho a
inner join exame e on a.codigo = e.fk_aparelho_codigo
order by a.marca, e.data_hora_realizacao;

""",conn)
# Out:
# <ipython-input-33-fe304a93024a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    aparelho_marca  disponivel data_hora_realizacao
# 0           Canon       False  2024-08-02 09:00:00
# 1           Canon       False  2024-08-10 08:45:00
# 2        Fujifilm        True  2024-08-07 14:00:00
# 3        Fujifilm        True  2024-08-14 12:15:00
# 4   GE Healthcare        True  2024-08-01 08:30:00
# 5   GE Healthcare        True  2024-08-09 16:00:00
# 6         Hitachi       False  2024-08-08 15:30:00
# 7         Hitachi       False  2024-08-15 13:00:00
# 8         Philips        True  2024-08-06 13:30:00
# 9         Siemens       False  2024-08-04 11:45:00
# 10        Siemens       False  2024-08-12 10:00:00
# 11        Toshiba        True  2024-08-05 12:00:00
# 12        Toshiba        True  2024-08-13 11:30:00
# 13         Toyota        True  2024-08-03 10:15:00
# 14         Toyota        True  2024-08-11 09:30:00

# %%
pd.read_sql_query("""
select
    la.codigo as laudo_codigo,
    la.data_hora_geracao,
    r.nome as radiologista_nome
from laudo la
inner join radiologista r on la.fk_radiologista_codigo = r.codigo
order by r.nome, la.data_hora_geracao;

""",conn)
# Out:
# <ipython-input-34-0003cbdf29a5>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     laudo_codigo   data_hora_geracao radiologista_nome
# 0              9 2024-08-09 15:00:00           Beiçola
# 1              2 2024-08-02 16:00:00        Dra. Clark
# 2              8 2024-08-08 14:00:00        Dra. Davis
# 3              1 2024-08-01 15:00:00      Dra. Johnson
# 4             15 2024-08-15 13:00:00   Dra. Lexie Grey
# 5             14 2024-08-14 12:00:00     Dra. Thompson
# 6             11 2024-08-11 17:00:00       Dra. Wilson
# 7             13 2024-08-13 11:00:00         Dr. Brown
# 8             12 2024-08-12 10:00:00           Dr. Cox
# 9              5 2024-08-05 11:00:00         Dr. House
# 10            10 2024-08-10 16:00:00           Dr. Lee
# 11             6 2024-08-06 12:00:00         Dr. Lewis
# 12             4 2024-08-04 10:00:00      Dr. Martinez
# 13             7 2024-08-07 13:00:00         Dr. Smith
# 14             3 2024-08-03 17:00:00        Dr. Watson

# %%
pd.read_sql_query("""
select
    pa.nome as patologia_nome,
    la.data_hora_geracao
from patologia pa
inner join patologia_laudo pl on pa.codigo = pl.fk_patologia_codigo
inner join laudo la on pl.fk_laudo_codigo = la.codigo
order by la.data_hora_geracao, pa.nome;


""",conn)
# Out:
# <ipython-input-36-5c1b19fadf68>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#                  patologia_nome   data_hora_geracao
# 0              Fratura de Fêmur 2024-08-01 15:00:00
# 1             Infecção Urinária 2024-08-01 15:00:00
# 2             Infecção Urinária 2024-08-01 15:00:00
# 3              Câncer de Pulmão 2024-08-02 16:00:00
# 4              Fratura de Fêmur 2024-08-02 16:00:00
# 5                   Tuberculose 2024-08-02 16:00:00
# 6               Diabetes Tipo 2 2024-08-03 17:00:00
# 7                Hepatite Viral 2024-08-03 17:00:00
# 8          Hipertensão Arterial 2024-08-04 10:00:00
# 9          Hipertensão Arterial 2024-08-04 10:00:00
# 10                 Saúde Normal 2024-08-05 11:00:00
# 11              Diabetes Tipo 2 2024-08-06 12:00:00
# 12             Fratura de Fêmur 2024-08-06 12:00:00
# 13                 Saúde Normal 2024-08-06 12:00:00
# 14         Hipertensão Arterial 2024-08-07 13:00:00
# 15            Infecção Urinária 2024-08-07 13:00:00
# 16                         Asma 2024-08-08 14:00:00
# 17              Diabetes Tipo 2 2024-08-08 14:00:00
# 18               Hepatite Viral 2024-08-08 14:00:00
# 19               Hepatite Viral 2024-08-08 14:00:00
# 20              Diabetes Tipo 1 2024-08-09 15:00:00
# 21                  Tuberculose 2024-08-09 15:00:00
# 22                         Asma 2024-08-10 16:00:00
# 23              Diabetes Tipo 1 2024-08-10 16:00:00
# 24                    Pneumonia 2024-08-10 16:00:00
# 25                         Asma 2024-08-11 17:00:00
# 26              Diabetes Tipo 2 2024-08-11 17:00:00
# 27  Doença Arterial Coronariana 2024-08-11 17:00:00
# 28               Hepatite Viral 2024-08-11 17:00:00
# 29               Câncer de Mama 2024-08-12 10:00:00
# 30               Câncer de Mama 2024-08-12 10:00:00
# 31                  Tuberculose 2024-08-12 10:00:00
# 32                         Asma 2024-08-13 11:00:00
# 33               Câncer de Mama 2024-08-13 11:00:00
# 34                    Pneumonia 2024-08-13 11:00:00
# 35              Diabetes Tipo 1 2024-08-14 12:00:00
# 36              Diabetes Tipo 1 2024-08-14 12:00:00
# 37         Hipertensão Arterial 2024-08-14 12:00:00
# 38                    Pneumonia 2024-08-14 12:00:00
# 39             Câncer de Pulmão 2024-08-15 13:00:00
# 40             Câncer de Pulmão 2024-08-15 13:00:00
# 41  Doença Arterial Coronariana 2024-08-15 13:00:00
# 42  Doença Arterial Coronariana 2024-08-15 13:00:00

# %%
pd.read_sql_query("""
select
    r.nome as radiologista_nome,
    count(la.codigo) as total_exames
from radiologista r
inner join laudo la on r.codigo = la.fk_radiologista_codigo
group by r.nome;

""",conn)
# Out:
# <ipython-input-37-43b199daf55a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    radiologista_nome  total_exames
# 0         Dr. Watson             1
# 1    Dra. Lexie Grey             1
# 2        Dra. Wilson             1
# 3          Dr. House             1
# 4          Dr. Brown             1
# 5            Dr. Lee             1
# 6            Beiçola             1
# 7       Dra. Johnson             1
# 8          Dr. Lewis             1
# 9         Dra. Clark             1
# 10     Dra. Thompson             1
# 11        Dra. Davis             1
# 12      Dr. Martinez             1
# 13         Dr. Smith             1
# 14           Dr. Cox             1

# %%
pd.read_sql_query("""
select
    to_char(e.data_hora_realizacao, 'YYYY-MM') as mes,
    count(e.codigo) as total_exames
from exame e
group by to_char(e.data_hora_realizacao, 'YYYY-MM')
order by mes;

""",conn)
# Out:
# <ipython-input-38-de4d5a2ee849>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#        mes  total_exames
# 0  2024-08            15

# %%
pd.read_sql_query("""
select
    extract(year from p.data_nasc) as ano_nascimento,
    count(p.codigo) as total_pacientes
from paciente p
group by extract(year from p.data_nasc)
order by ano_nascimento;

""",conn)
# Out:
# <ipython-input-39-5d9ea59ed40e>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     ano_nascimento  total_pacientes
# 0              7.0                1
# 1           1412.0                1
# 2           1605.0                1
# 3           1809.0                1
# 4           1883.0                1
# 5           1921.0                1
# 6           1945.0                1
# 7           1956.0                1
# 8           1967.0                1
# 9           1978.0                1
# 10          1979.0                1
# 11          1991.0                1
# 12          1996.0                1
# 13          2001.0                1
# 14          2430.0                1

# %%
pd.read_sql_query("""
select p.nome as patologia, count( pl.codigo) as total_laudos from patologia p
join patologia_laudo pl on p.codigo = pl.fk_patologia_codigo group by p.nome
order by total_laudos desc;

""",conn)
# Out:
# <ipython-input-40-b1c756a270e8>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#                       patologia  total_laudos
# 0               Diabetes Tipo 1             4
# 1          Hipertensão Arterial             4
# 2                          Asma             4
# 3               Diabetes Tipo 2             4
# 4                Hepatite Viral             4
# 5              Fratura de Fêmur             3
# 6             Infecção Urinária             3
# 7   Doença Arterial Coronariana             3
# 8                     Pneumonia             3
# 9                Câncer de Mama             3
# 10                  Tuberculose             3
# 11             Câncer de Pulmão             3
# 12                 Saúde Normal             2

# %%
pd.read_sql_query("""
select e.codigo as exame_codigo,
count(pr.codigo) as total_predicoes
from exame e
left join predicao pr on e.codigo = pr.fk_registro_exame_codigo
group by e.codigo
order by total_predicoes desc;

""",conn)
#
# Out:
# <ipython-input-41-c1a59184514a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     exame_codigo  total_predicoes
# 0              1                4
# 1              2                4
# 2              3                4
# 3              5                4
# 4              4                4
# 5              7                3
# 6              8                3
# 7             10                3
# 8              6                3
# 9             11                3
# 10             9                3
# 11            13                3
# 12            15                3
# 13            14                3
# 14            12                3

# %%
pd.read_sql_query("""
select
    p.nome as paciente_nome,
    e.data_hora_realizacao as exame_data
from paciente p
left join exame e on p.codigo = e.fk_paciente_codigo
order by p.nome;

""",conn)
#####
# Out:
# <ipython-input-42-783b4d12d350>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#       paciente_nome          exame_data
# 0      Bart Simpson 2024-08-09 16:00:00
# 1      Bola de Neve 2024-08-06 13:30:00
# 2    Carlinhos Maia 2024-08-03 10:15:00
# 3         Chewbacca 2024-08-13 11:30:00
# 4       Don Quixote 2024-08-10 08:45:00
# 5   Edgar Allan Poe 2024-08-04 11:45:00
# 6       Franz Kafka 2024-08-05 12:00:00
# 7          Garfield 2024-08-07 14:00:00
# 8     Homer Simpson 2024-08-08 15:30:00
# 9        Joana Darc 2024-08-01 08:30:00
# 10    Marcelo Rossi 2024-08-02 09:00:00
# 11          Pikachu 2024-08-14 12:15:00
# 12            Shrek 2024-08-12 10:00:00
# 13          Smeagol 2024-08-15 13:00:00
# 14  Winnie the Pooh 2024-08-11 09:30:00

# %%
pd.read_sql_query("""
select
    e.codigo as exame_codigo,
    a.marca as aparelho_marca
from exame e
right join aparelho a on e.fk_aparelho_codigo = a.codigo
order by e.codigo;

""",conn)
# Out:
# <ipython-input-43-2ae553e862b3>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#     exame_codigo aparelho_marca
# 0            1.0  GE Healthcare
# 1            2.0          Canon
# 2            3.0         Toyota
# 3            4.0        Siemens
# 4            5.0        Toshiba
# 5            6.0        Philips
# 6            7.0       Fujifilm
# 7            8.0        Hitachi
# 8            9.0  GE Healthcare
# 9           10.0          Canon
# 10          11.0         Toyota
# 11          12.0        Siemens
# 12          13.0        Toshiba
# 13          14.0       Fujifilm
# 14          15.0        Hitachi
# 15           NaN     Carestream
# 16           NaN        Hologic
# 17           NaN        Mindray
# 18           NaN      Medtronic
# 19           NaN        Biplane
# 20           NaN       Shimadzu
# 21           NaN           Agfa

# %%
pd.read_sql_query("""
select
    r.nome as radiologista_nome,
    la.data_hora_geracao as laudo_data
from radiologista r
full join laudo la on r.codigo = la.fk_radiologista_codigo
order by r.nome;

""",conn)
# Out:
# <ipython-input-44-a7098fb2e376>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#    radiologista_nome          laudo_data
# 0            Beiçola 2024-08-09 15:00:00
# 1         Dra. Clark 2024-08-02 16:00:00
# 2         Dra. Davis 2024-08-08 14:00:00
# 3       Dra. Johnson 2024-08-01 15:00:00
# 4    Dra. Lexie Grey 2024-08-15 13:00:00
# 5      Dra. Thompson 2024-08-14 12:00:00
# 6        Dra. Wilson 2024-08-11 17:00:00
# 7          Dr. Brown 2024-08-13 11:00:00
# 8            Dr. Cox 2024-08-12 10:00:00
# 9          Dr. House 2024-08-05 11:00:00
# 10           Dr. Lee 2024-08-10 16:00:00
# 11         Dr. Lewis 2024-08-06 12:00:00
# 12      Dr. Martinez 2024-08-04 10:00:00
# 13         Dr. Smith 2024-08-07 13:00:00
# 14        Dr. Watson 2024-08-03 17:00:00

# %%
pd.read_sql_query("""
select
    pa.nome as patologia_nome,
    pr.confiabilidade as predicao_confiabilidade
from patologia pa
left join predicao pr on pa.codigo = pr.fk_patologia_codigo
order by pa.nome;

""",conn)
# Out:
# <ipython-input-45-3ac1f148ad4c>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#                  patologia_nome  predicao_confiabilidade
# 0                          Asma                      NaN
# 1                Câncer de Mama                      NaN
# 2              Câncer de Pulmão                      NaN
# 3               Diabetes Tipo 1                      NaN
# 4               Diabetes Tipo 2                     0.89
# 5               Diabetes Tipo 2                     0.90
# 6               Diabetes Tipo 2                     0.88
# 7               Diabetes Tipo 2                     0.87
# 8   Doença Arterial Coronariana                      NaN
# 9              Fratura de Fêmur                      NaN
# 10               Hepatite Viral                      NaN
# 11         Hipertensão Arterial                      NaN
# 12            Infecção Urinária                      NaN
# 13                    Pneumonia                     0.91
# 14                    Pneumonia                     0.91
# 15                    Pneumonia                     0.88
# 16                    Pneumonia                     0.92
# 17                    Pneumonia                     0.89
# 18                    Pneumonia                     0.90
# 19                    Pneumonia                     0.90
# 20                    Pneumonia                     0.93
# 21                    Pneumonia                     0.92
# 22                    Pneumonia                     0.88
# 23                    Pneumonia                     0.89
# 24                    Pneumonia                     0.90
# 25                 Saúde Normal                     0.82
# 26                 Saúde Normal                     0.80
# 27                 Saúde Normal                     0.83
# 28                 Saúde Normal                     0.81
# 29                 Saúde Normal                     0.82
# 30                 Saúde Normal                     0.84
# 31                 Saúde Normal                     0.80
# 32                 Saúde Normal                     0.79
# 33                 Saúde Normal                     0.85
# 34                 Saúde Normal                     0.80
# 35                 Saúde Normal                     0.82
# 36                 Saúde Normal                     0.83
# 37                 Saúde Normal                     0.81
# 38                 Saúde Normal                     0.84
# 39                 Saúde Normal                     0.80
# 40                 Saúde Normal                     0.85
# 41                 Saúde Normal                     0.79
# 42                  Tuberculose                      NaN

# %%
pd.read_sql_query("""
select
    a.marca as aparelho_marca
from aparelho a
where a.codigo in (
    select e.fk_aparelho_codigo
    from exame e
    inner join registro_exame r on e.codigo = r.fk_exame_codigo
    where r.condicaoEhPatologica = true
);

""",conn)
# Out:
# <ipython-input-46-9fe0332c01b5>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#   aparelho_marca
# 0        Siemens
# 1  GE Healthcare
# 2        Toshiba
# 3          Canon
# 4       Fujifilm
# 5         Toyota

# %%
pd.read_sql_query("""
select
    p.nome as paciente_nome
from paciente p
where p.codigo not in (
    select e.fk_paciente_codigo
    from exame e
    inner join laudo l on e.codigo = l.fk_exame_codigo
);


""",conn)
# Out:
# <ipython-input-50-cc308f2bc476>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
# Empty DataFrame
# Columns: [paciente_nome]
# Index: []

# %%
pd.read_sql_query("""
select
    r.nome as radiologista_nome
from radiologista r
where r.codigo not in (
    select l.fk_radiologista_codigo
    from laudo l
);


""",conn)
# Out:
# <ipython-input-52-69d6e75148c3>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
# Empty DataFrame
# Columns: [radiologista_nome]
# Index: []

# %%
pd.read_sql_query("""
select
    pa.nome as patologia_nome,
    count(pl.fk_patologia_codigo) as numero_ocorrencias
from patologia pa
inner join patologia_laudo pl on pa.codigo = pl.fk_patologia_codigo
group by pa.nome
having count(pl.fk_patologia_codigo) > (
    select avg(numero_ocorrencias)
    from (
        select count(*) as numero_ocorrencias
        from patologia_laudo
        group by fk_patologia_codigo
    ) as subconsulta
);


""",conn)
# Out:
# <ipython-input-53-8727b9efe3e7>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#          patologia_nome  numero_ocorrencias
# 0        Hepatite Viral                   4
# 1                  Asma                   4
# 2       Diabetes Tipo 2                   4
# 3  Hipertensão Arterial                   4
# 4       Diabetes Tipo 1                   4
